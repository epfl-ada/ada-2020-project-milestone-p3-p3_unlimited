# %% [markdown]
# ## Conversation Gone Awry

# %%
import os

import numpy as np
import pandas as pd
from scipy import stats

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, LeaveOneGroupOut
from sklearn.feature_selection import f_classif, SelectPercentile

from collections import defaultdict
from functools import partial
from multiprocessing import Pool

from convokit import download
from convokit.prompt_types import PromptTypeWrapper
from convokit import PolitenessStrategies
from convokit import Corpus, Speaker, Utterance
from convokit import Classifier

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load dataset

# %%
# OPTION 1: DOWNLOAD CORPUS 
# UNCOMMENT THESE LINES TO DOWNLOAD CORPUS
# DATA_DIR = ''
#AWRY_ROOT_DIR = download('conversations-gone-awry-corpus', data_dir=DATA_DIR)

# OPTION 2: READ PREVIOUSLY-DOWNLOADED CORPUS FROM DISK
# UNCOMMENT THIS LINE AND REPLACE WITH THE DIRECTORY WHERE THE TENNIS-CORPUS IS LOCATED
AWRY_ROOT_DIR = 'E:\EPFL_Courses\ADA\milestone-p3_data\conversations-gone-awry-corpus'

awry_corpus = Corpus(AWRY_ROOT_DIR)
awry_corpus.load_info('utterance',['parsed'])

awry_corpus = awry_corpus.filter_conversations_by(lambda convo: convo.meta['annotation_year'] == '2018')

# %%
awry_corpus.print_summary_stats()
# Out:
# Number of Speakers: 2010
# Number of Utterances: 6363
# Number of Conversations: 1168

# %%
awry_corpus.get_speakers_dataframe()
# Out:
#               vectors
# id
# Sirex98            []
# 2005               []
# WilyD              []
# H20h0us391         []
# Billzilla          []
# ...               ...
# Seregain           []
# Gabr-el            []
# Raspor             []
# FeloniousMonk      []
# Ec5618             []
#
# [2010 rows x 1 columns]

# %%
for conv in awry_corpus.iter_conversations():
    spk_list = conv.get_chronological_speaker_list()
    spks = []
    for item in spk_list:
        spk = item.id
        spks.append(spk)
    print(set(spks))
# Out:
# {'2005', 'Sirex98'}
# {'2005', 'WilyD'}
# {'H20h0us391', 'Billzilla'}
# {'The Evil Spartan', 'AuburnPilot', 'Billzilla'}
# {'Morton devonshire', 'Captainktainer', 'Commodore Sloat'}
# {'Commodore Sloat', 'RonCram'}
# {'Rueben lys', 'Jaiiaf', 'Idleguy', 'Kazimostak'}
# {'Idleguy', '129.100.224.185'}
# {'Can.u.spel', 'Alex32165', 'Greswik'}
# {'Nautilogos', 'Dr. Blofeld', 'Greswik'}
# {'Ferociouslettuce', 'Extransit'}
# {'Orangemike', 'Wangtopgun'}
# {'134.173.61.53', 'Skomorokh', 'TallNapoleon', 'SteveWolfer'}
# {'Stevewunder', 'SteveWolfer', 'Snowded', 'ChildofMidnight'}
# {'Filll', 'Hrafn', 'NCdave'}
# {'Hrafn', 'BigBang616'}
# {'Achilton', 'Hrafn', 'WLU'}
# {'Hrafn', 'Mike0001'}
# {'Milowent', 'SRMach5B'}
# {'Milowent', 'JamesBWatson', 'Otterathome'}
# {'Daicaregos', 'Malleus Fatuorum'}
# {'Eric Corbett', 'Dougatwiki'}
# {'Jasonbres', 'Acps110'}
# {'AndyTheCop', 'Jasonbres'}
# {'ConfuciusOrnis', 'Nv8200pa', 'Orangemarlin'}
# {'ConfuciusOrnis', 'ZayZayEM'}
# {'ViriiK', 'Alan.ca', 'Ryulong', 'Colin Keigher'}
# {'Ryulong', 'Zaphnathpaaneah'}
# {'Yankees10', 'EdJohnston', 'Johnny Spasm'}
# {'Halvorsen brian', 'Giants27'}
# {'AnemoneProjectors', 'Rodhullandemu'}
# {'AnemoneProjectors', 'Extremador'}
# {'Kungfuadam', 'SPUI'}
# {'Nlu', 'SPUI'}
# {'AnemoneProjectors', '80.5.133.45', 'Alex250P'}
# {'Bluebolt94', 'AnemoneProjectors', 'Arjoccolenty'}
# {'Pax Arcane', 'DaveApter'}
# {'Pax Arcane', 'DaveApter', 'Spacefarer'}
# {'Kmhkmh', 'Gimmetoo', 'Gill110951'}
# {'Glkanter', 'Rick Block'}
# {'Phil Sandifer', 'TreasuryTag', 'Melsaran'}
# {'Scarian', 'TreasuryTag'}
# {'Baseball Bugs', 'Mallerd'}
# {'BethelRunner', 'Macrakis', 'Baseball Bugs'}
# {'Ryulong', 'Racepacket'}
# {'Ryulong', 'Racepacket'}
# {'Madhatter9max', 'JasonAQuest', '24.107.202.65', 'Calor'}
# {'199.80.117.25', '212.137.33.65', 'Supergodzilla2090'}
# {'2over0', 'Martin Hogbin', 'Tony Sidaway', 'MalcolmMcDonald'}
# {'Deskana', 'Nard the Bard', 'Tony Sidaway'}
# {'Randall Brackett', 'Tony Sidaway'}
# {'JohnnyBGood', 'Tony Sidaway'}
# {'Tony Sidaway', 'Dominic', 'MSJapan'}
# {'Tony Sidaway', 'Agriculture'}
# {'Dtobias', 'Guettarda', 'Mike Garcia'}
# {'66.36.136.123', 'Mike Garcia'}
# {'Irpen', 'AndriyK'}
# {'Irpen', 'AndriyK'}
# {'William S. Saturn', 'Dabomb87', 'The Rambling Man'}
# {'Dabomb87', 'Deb'}
# {'69.196.139.250', 'Zora', 'Zereshk'}
# {'Zereshk', 'Ahwaz', 'Hajjagha'}
# {'WarthogDemon', 'Kusma'}
# {'Kiteinthewind', 'Kusma'}
# {'Revizionist', 'NikNovi', 'Köbra'}
# {'Revizionist', 'Future Perfect at Sunrise', 'Köbra'}
# {'The Ogre', 'Provocateur', 'Jimp'}
# {'Burgas00', 'Golbez'}
# {'Dogman15', 'Evan1109', 'PhotoCatBot'}
# {'72.67.194.21', 'TheWarlock', 'Azuran'}
# {'Beeblebrox', 'Caspian blue'}
# {'Thejadefalcon', 'Beeblebrox', '75.141.100.115'}
# {'Koalorka', 'Martin H.'}
# {'Koalorka', 'Dave1185'}
# {'Saimaroimaru 2008', 'BrothaTimothy'}
# {'SmokeyTheCat', 'FuriousFreddy'}
# {'Elcastigador', 'GregKaye', 'Lulu of the Lotus-Eaters'}
# {'Scjessey', '71.57.8.103', '64.208.230.145', 'Lulu of the Lotus-Eaters'}
# {'Neo Guyver', 'Yenaldooshi', 'Sukecchi', 'Ged UK', 'SLJCOAAATR 1'}
# {'Lerdthenerd', 'Ged UK', 'SLJCOAAATR 1', 'Sukecchi'}
# {'Friday', 'Majorly', 'Trey'}
# {'Trey', 'Zscout370'}
# {'Brewcrewer', 'Tiptoety', 'Spanneraol', 'JustSomeRandomGuy32', 'Giants27', 'Anthony Bradbury'}
# {'Dshibshm', 'Brewcrewer', 'JustSomeRandomGuy32'}
# {'Kos42', 'EdJohnston', 'Carolmooredc'}
# {'Knowledgeum', 'EdJohnston', 'Zell65'}
# {'Frazzydee', 'AngryParsley'}
# {'Davenbelle', 'AngryParsley'}
# {'Sirmylesnagopaleentheda', 'A Sniper'}
# {'Koavf', 'ThuranX'}
# {'Persian Poet Gal', 'Rgoodermote', 'Balloonman'}
# {'PAVA11', 'Die4Dixie'}
# {'CarTick', 'Skyring', 'Matilda'}
# {'Skyring', 'Matilda', 'Lester'}
# {'Kelapstick', 'Drmies', 'Bongomatic'}
# {'Drmies', 'El Mayimbe'}
# {'Drmies', 'Amandajm'}
# {'Gillis', 'Drmies'}
# {'Biruitorul', 'Ronline', 'Icar'}
# {'Telex', '70.48.94.61'}
# {'Jam01', 'Mike 7', 'Bhadani', 'Daniel5127'}
# {'24.61.157.174', 'Irishguy'}
# {'Thatguy96', 'CORNELIUSSEON', 'Gadget850'}
# {'Thatguy96', 'BonesBrigade', 'Gadget850', 'Riddley'}
# {'Kelly Martin', 'Randall Brackett'}
# {'Kelly Martin', 'Everyking'}
# {'Wikidea', 'Aeonx'}
# {'Wikidea', 'THF'}
# {'Orangemarlin', 'Brothejr'}
# {'Dave souza', '24.19.45.177', 'Casliber', 'Orangemarlin'}
# {'Orangemarlin', 'Neutralhomer'}
# {'Guettarda', 'Orangemarlin'}
# {'TimVickers', 'Orangemarlin'}
# {'70.107.246.88', 'Icairns', 'Orangemarlin'}
# {'Filll', 'Standonbible', 'Orangemarlin'}
# {'Turtlescrubber', 'Curious Blue', 'Orangemarlin'}
# {'ElinorD', 'Filll', 'Orangemarlin'}
# {'ProtoCat', 'Orangemarlin'}
# {'Anetode', 'JBsupreme', 'ImNotRichImStillLyin'}
# {'ImNotRichImStillLyin', 'Tasc0'}
# {'JuJube', 'Lasttiger', 'Vgamer101'}
# {'143.107.4.202', '24.209.242.49', 'Lasttiger'}
# {'IanManka', 'Visviva', 'Splash', 'MrDolomite', 'Ral315'}
# {'Jon Harald Søby', 'Vanished user 5zariu3jisj0j4irj', 'Ravedave'}
# {'Tazmaniacs', 'Zeq'}
# {'Tazmaniacs', 'Zeq'}
# {'Obersachse', 'Alexandria'}
# {'Hurricanefan25', 'Malleus Fatuorum', 'Hersfold'}
# {'Brookie', 'Nakassis', 'Teadude'}
# {'Brookie', 'Mdawg414', 'Nv8200pa'}
# {'Liam20112011', 'Noformation'}
# {'Archiveman2011', 'SineBot', 'Noformation'}
# {'Ian Rose', 'Two Hearted River'}
# {'Two Hearted River', 'Be Black Hole Sun', 'CarpetCrawler'}
# {'Million Little Gods', 'Feline1'}
# {'Juryen~enwiki', 'Feline1'}
# {'Lawrence Cohen', 'Random832', 'SlimVirgin'}
# {'Lawrence Cohen', 'JzG'}
# {'Tony1', 'Dabomb87', 'Locke Cole'}
# {'GFHandel', 'Tony1', 'Kendrick7'}
# {'AGK', 'SynergyStar'}
# {'Pgdn001', 'SynergyStar'}
# {'Beeblebrox', 'TaivoLinguist', 'Elockid', 'TopGun'}
# {'DBigXray', 'TopGun'}
# {'Feline1', '67.161.159.218', 'Drowse'}
# {'Jon Harald Søby', 'Feline1', '!melquiades'}
# {'Duchamps comb', 'Tqbf', 'HelloAnnyong'}
# {'Duchamps comb', 'Tqbf', 'Monsieurdl'}
# {'Giano II', 'Ryan Postlethwaite'}
# {'Daniel', 'One Night In Hackney', 'Giano II'}
# {'AgnosticPreachersKid', 'ChildofMidnight'}
# {'AgnosticPreachersKid', 'South Bay'}
# {'AgnosticPreachersKid', 'Philippe', 'Realist2', 'Becksguy'}
# {'AgnosticPreachersKid', 'Realist2'}
# {'Certified Gangsta', 'Maowang', 'Folic Acid'}
# {'Certified Gangsta', 'Ideogram', 'Blueshirts'}
# {'Occuserpens', 'Nil Einne'}
# {'66.189.11.112', 'Epa101'}
# {'Idont Havaname', 'Howrealisreal', '69.220.248.76', 'Bash', '70.249.34.67'}
# {'Howrealisreal', '70.249.34.67'}
# {'Duckecho', 'GordonWatts', 'FuelWagon'}
# {'Astanhope', 'Mia-Cle', 'GordonWatts', 'Fangz', 'FuelWagon'}
# {'Nku pyrodragon', 'Styrofoam1994'}
# {'Nku pyrodragon', 'Styrofoam1994'}
# {'Jguk', 'Wetman'}
# {'IMeowbot', 'SPUI'}
# {'RichardWeiss', '72.0.180.2'}
# {'Erachima', 'Freechild', 'RichardWeiss'}
# {'CloudNine', 'WesleyDodds', 'NSR77'}
# {'Mr.Gigglestein', 'CloudNine', 'WesleyDodds'}
# {'Mad$', 'Ted87', '146.244.138.26'}
# {'Ted87', '68.73.57.30'}
# {'Tubesship', 'Avala', '71.254.125.81', 'Alchaemia', 'EmilJ', 'IJA'}
# {'Max Mux', 'Avala'}
# {'84.134.93.18', 'Avala', 'Jakezing', 'Max Mux', 'Bazonka', 'DaQuirin'}
# {'Max Mux', 'Jakezing'}
# {'Kmccoy', 'Brothejr'}
# {'Brothejr', 'Die4Dixie'}
# {'Yintan', 'Passportguy'}
# {'Duchamps comb', 'Passportguy'}
# {'Fnlayson', 'Dave1185'}
# {'Mecanismo', 'Dave1185'}
# {'Ceha', 'Toddst1'}
# {'Cyberia23', 'Toddst1'}
# {'Fran46', 'Azumanga1', 'Toddst1'}
# {'HalfShadow', 'Carpathy2009', 'Toddst1'}
# {'Backvoods', '135.214.42.162', 'Andkore', 'M412k'}
# {'Tyguy92', 'Andkore', 'MacRusgail', 'Man vyi', 'Regan123', 'Derek Ross', '82.21.204.72', 'Martinp23', 'Lurker'}
# {'TJ Spyke', 'Wrestlinglover', 'Tony2Times', 'ArcAngel', 'Gloss', 'Truco', 'Darrenhusted'}
# {'Wrestlinglover', 'Truco', 'Jameboy', 'Tony2Times'}
# {'GaryColemanFan', 'ThinkBlue', 'Scorpion0422'}
# {'D.M.N.', 'Nikki311', 'Tvp119'}
# {'Yankees76', 'Attilios'}
# {'Gavinthesavage', 'Ravenswing', 'Attilios'}
# {'Indubitably', 'The undertow', 'Woody'}
# {'Indubitably', 'The undertow'}
# {'KellyAna', 'Doolkid'}
# {'Rjd0060', 'KellyAna'}
# {'SiobhanHansa', 'RHB', 'Rockinthefarm', 'AuburnPilot'}
# {'AuburnPilot', 'BricksFromEurope'}
# {'Guildenrich', '66.130.192.44', 'Tide rolls'}
# {'Khirurg', 'Balkanian`s word', 'Macrakis', 'Alexikoua', 'Interestedinfairness'}
# {'Mr. Tibbs', 'Zer0faults'}
# {'Añoranza', 'Zer0faults', 'DHeyward'}
# {'Hiding', 'Thryduulf', 'Amarkov'}
# {'Hiding', 'Hipocrite'}
# {'Plrk', '72.38.151.189'}
# {'Plrk', 'Buzza69'}
# {'DreamGuy', 'JamesBWatson', 'Esasus'}
# {'Protonk', 'Smooth0707', 'Esasus', 'Proxy User'}
# {'68.83.173.129', 'JuJube'}
# {'Kid Sonic', 'JuJube'}
# {'Falcon8765', 'MissionNPOVible'}
# {'Farsight001', 'MissionNPOVible'}
# {'Yariau neko', '24.183.205.52', 'Hetelllies'}
# {'Yariau neko', 'Firithfenion', 'Hetelllies'}
# {'Pedro', 'Acalamari'}
# {'Keeper76', 'Pedro'}
# {'Strange Passerby', 'Ironholds'}
# {'DePiep', 'Ironholds', 'Fluffernutter', 'Vanisaac'}
# {'TexasAndroid', 'CattleGirl', '195.72.234.172'}
# {'CD Amadeus', 'Orfen', '152.163.100.138'}
# {'Mjroots', 'Jasepl'}
# {'Jasepl', 'Tedder', 'Rhp26'}
# {'41.199.142.69', 'Wikipedian Penguin', 'HusseinIED'}
# {'Legolas2186', 'Portillo', '90.210.203.77'}
# {'Kaldari', 'Ryoung122', 'Paul57~enwiki'}
# {'Acefitt', 'Sean mc sean'}
# {'Killervogel5', '5 albert square', 'Halvorsen brian'}
# {'Yankees10', 'Giants27'}
# {'Hajji Piruz', 'Rayis', 'Asabbagh', 'Nepaheshgar'}
# {'Ioj', '129.70.14.2'}
# {'Evb-wiki', 'Cheesy mike', 'Bri', 'Ww2censor'}
# {'Evb-wiki', 'Cheesy mike', 'Motorrad-67'}
# {'The Thunderer', 'Alison', 'Traditional unionist'}
# {'Maxburgoyne', 'The Thunderer'}
# {'Bishzilla', 'Dogriggr'}
# {'Santa on Sleigh', 'Sluzzelin', 'Bishzilla'}
# {'Phaedriel', 'Bishzilla', 'KillerChihuahua'}
# {'Bishzilla', 'Lsi john', 'Bishapod'}
# {'Adabow', 'Legolas2186', 'Lil-unique1'}
# {'Legolas2186', 'Jivesh boodhun', 'Ryoga Godai'}
# {'Bilby', 'Peter Damian (old)'}
# {'Canterbury Tail', 'Bilby', 'Peter Damian (old)'}
# {'Thumperward', 'Protious', 'Lambiam'}
# {'Trovatore', 'VanishedUserABC'}
# {'Black Kite', 'Crowsnest', 'O Fenian'}
# {'BigDunc', 'NewIreland2009'}
# {'Cptnono', 'Hans Adler', 'Ingolfson', '24.188.207.20'}
# {'Cptnono', '220.101.28.25'}
# {'203.213.65.249', 'Symaps', 'Splash', '165.228.245.66'}
# {'Karmaisking', 'Gregalton'}
# {'Trezjr', 'Whidbey', '66.90.151.79'}
# {'195.93.21.100', 'Batman2005'}
# {'206.251.10.21', 'Glimmer721', 'JabocJacobOhYeah'}
# {'John', 'Murry1975'}
# {'Newyorkbrad', '24.57.67.245', 'MZMcBride'}
# {'RedSquirrel', 'MZMcBride', 'Closedmouth'}
# {'Collect', 'Killiondude'}
# {'AGK', 'MZMcBride'}
# {'D.E. Watters', 'Winged Brick', 'Patton123'}
# {'Steelerfan-94', 'Winged Brick'}
# {'Promethean', 'Mike R'}
# {'T3chl0v3r', 'NJA', 'Promethean'}
# {'Sideiron', 'TwentiethApril1986', 'WereSpielChequers', 'Somerandomnerd', 'RaseaC', 'Uncle G'}
# {'RaseaC', 'Isonomia', 'Uncle G'}
# {'Anna Frodesiak', 'SineBot', 'SdeClercq1', 'Wombat24'}
# {'86.133.142.191', 'Anna Frodesiak', 'MichaelWestbrook'}
# {'Islander', 'CJ2005B', 'Cobaltbluetony', 'Tool2Die4', '72.92.4.157'}
# {'CJ2005B', 'Islander'}
# {'Doctorbruno', 'Matt Crypto', 'Bhadani'}
# {'Hraefen', 'Doctorbruno', '67.164.5.90', 'Diberri'}
# {'Kimchi.sg', 'Deathphoenix'}
# {'Kimchi.sg', 'Sam Marcy', '202.7.166.166'}
# {'Moxy', 'Resident Mario'}
# {'Fetchcomms', 'Resident Mario'}
# {'Carcharoth', 'Avraham', 'Zaharous'}
# {'Amoruso', 'Avraham', 'Sarastro777', 'LifeEnemy', 'Markovich292'}
# {'Fwdixon', 'Dcfleck', 'WAvegetarian'}
# {'69.205.1.91', 'Sitearm'}
# {'Tothwolf', 'Chzz'}
# {'Tothwolf', 'Skyerise'}
# {'Bellerophon', 'Baseball Bugs', '67.180.161.183'}
# {'Bellerophon', 'Tomas Gilbfarb'}
# {'Mttll', 'Babakexorramdin'}
# {'Mttll', 'Khirurg'}
# {'Cptnono', 'Nableezy'}
# {'Stellarkid', 'Tedder', 'Nableezy'}
# {'Status', 'Xwomanizerx', 'Carmaker1', 'Ipodnano05'}
# {'Legolas2186', 'Petergriffin9901', 'Candyo32'}
# {'Lar', 'Tryptofish', 'The Wordsmith'}
# {'Lar', 'The Wordsmith', 'William M. Connolley'}
# {'Raoul1', 'SoSaysChappy', 'Jombage', 'TMV943'}
# {'SmokeyTheCat', 'Angelofdeath275'}
# {'Polargeo', 'Peridon'}
# {'78.13.165.121', 'Polargeo'}
# {'Woohookitty', 'Benjamin Gatti'}
# {'Woohookitty', 'Benjamin Gatti', 'Simesa'}
# {'Marasmusine', 'MelmothWanders'}
# {'Bridies', 'Wiki libs'}
# {'Legolas2186', 'GagaLoveGame', 'Smanu'}
# {'Legolas2186', 'GagaLoveGame', 'Smanu'}
# {'76.64.152.111', 'Atama', 'Looie496', 'Frmatt'}
# {'Atama', 'WikiQc', 'Frmatt'}
# {'LiquidGhoul', 'Guettarda', 'Marskell'}
# {'222.155.21.111', 'Venu62'}
# {'Farhansher', 'Tariqabjotu'}
# {'Tariqabjotu', 'Mary K. Sponze'}
# {'Dweller', 'SCZenz', 'Hipocrite'}
# {'SCZenz', 'Hipocrite'}
# {'Jayen466', 'Malkinann', 'Jinnai'}
# {'70.240.200.44', '70.240.217.50', 'Nihonjoe'}
# {'TreasuryTag', 'Baseball Bugs'}
# {'TreasuryTag', 'Nyttend'}
# {'Looper5920', 'Elonka'}
# {'ERcheck', 'JPatrickBedell', 'Looper5920'}
# {'Aaroncrick', 'VirtualSteve', 'Bidgee', 'D climacus', 'Sarah'}
# {'Codman', 'Bidgee'}
# {'CycloneGU', 'HJ Mitchell'}
# {'Tbhotch', 'Kudzu1', 'HJ Mitchell'}
# {'DavidOaks', 'TruthIIPower'}
# {'TruthIIPower', 'Haymaker', 'Awickert'}
# {'Swatjester', 'Jiang'}
# {'160.39.195.88', 'Jiang'}
# {'TomStar81', 'Tony1'}
# {'Coloane', 'Roger Davies', 'Tony1', 'Efe'}
# {'Bedford', 'FeanorStar7', 'Belovedfreak'}
# {'Bedford', 'Elkman', 'Doncram', 'Lar', 'Daniel Case'}
# {'Hesperian', 'Cygnis insignis'}
# {'Yandman', 'Cygnis insignis', 'Durova'}
# {'DeadEyeArrow', 'Enigmaman', 'Loren.wilton'}
# {'Marc KJH', 'TheProf07'}
# {'Simple Bob', 'Rodw', '94.195.145.155'}
# {'Simple Bob', 'Iranian86Footballer'}
# {'Javert', 'Vicenarian'}
# {'Vicenarian', 'User F203'}
# {'Nikkul', 'Robertgreer', 'Crazy-dancing', 'Abductive'}
# {'208.82.161.66', 'Abductive'}
# {'Victoriaearle', 'CaroleHenson'}
# {'Victoriaearle', 'Malleus Fatuorum'}
# {'Skyerise', 'Freechild'}
# {'76.121.180.74', '24.17.63.79', 'Skyerise'}
# {'Daryou', 'Reisio', 'Robdurbar'}
# {'Daryou', 'Koavf', 'Arre', 'Reisio', 'Robdurbar'}
# {'Kralizec!', 'HeadMouse', 'Maelwys'}
# {'Kralizec!', 'HiDrNick', 'Either way', 'Yamla', 'HeadMouse'}
# {'Stephan Schulz', 'Asams10'}
# {'Wallaceburghistory', 'Asams10'}
# {'Richard001', 'Wobble', 'Ramdrake', 'Jagz'}
# {'Ramdrake', 'Jagz', 'Wsiegmund'}
# {'Cyberfox1954', 'Older and ... well older'}
# {'Cyberfox1954', 'John'}
# {'Javert', 'Vicenarian', 'Spongefrog'}
# {'Javert', 'Vicenarian'}
# {'WebHamster', 'SimonTrew'}
# {'Noloop', 'WebHamster'}
# {'Wolfdog1', 'WebHamster'}
# {'Prester John', 'WebHamster'}
# {'Pascal.Tesson', '141.209.196.70', 'LifeEnemy'}
# {'Danteferno', '88.104.124.12', 'Gofur'}
# {'Iqinn', 'V7-sport'}
# {'V7-sport', 'Jrtayloriv'}
# {'25162995', 'Snowded', 'Maxted101'}
# {'Alexandre8', 'Slatersteven', 'Snowded'}
# {'JzG', 'One Night In Hackney'}
# {'Mccready', 'JzG'}
# {'Wikiwiserick', 'Rhode Island Red'}
# {'Wikiwiserick', 'Rhode Island Red'}
# {'LesPhilky', 'EdJohnston', 'Kuru', 'GarnetAndBlack'}
# {'Hammersoft', '129.252.69.40', 'Zscout370'}
# {'Neptunerover', 'Gigs'}
# {'TreasuryTag', 'Neptunerover'}
# {'Hux', 'MikeHobday', 'Ian Davies Friend'}
# {'213.94.176.243', 'IanDavies', '193.1.88.12'}
# {'-RonTaril-', 'MONGO', 'Agriculture'}
# {'Tverbeek', 'Agriculture'}
# {'Wehwalt', 'RMHED', 'ChildofMidnight'}
# {'RMHED', 'Malleus Fatuorum'}
# {'Ginger Warrior', 'SpecialWindler', 'Gibson Flying V'}
# {'SpecialWindler', 'Sticks66', 'Gibson Flying V'}
# {'Supreme Deliciousness', 'AlasdairEdits', 'Breein1007', '131.111.225.81'}
# {'Newt Winkler', 'Breein1007'}
# {'Nug', 'DarknessShines2', 'Ncmvocalist'}
# {'DarknessShines2', 'Tony Sidaway'}
# {'BrendanFrye', 'TreyGeek'}
# {'Arizaalberto', 'BrendanFrye'}
# {'Sole Soul', 'SusanLesch', 'Fetchcomms', 'Epeefleche'}
# {'SusanLesch', 'Huik01'}
# {'Masem', 'Innotata', 'Postdlf'}
# {'Hammersoft', 'Black Kite', 'DMacks'}
# {'White Shadows', 'Buggie111'}
# {'White Shadows', 'Wehwalt', 'TonyTheTiger'}
# {'Stephan Schulz', 'Nathan Johnson'}
# {'Nathan Johnson', 'Scottywong'}
# {'Morenooso', 'Scrivener-uki', 'ResignBen16', 'PamD'}
# {'Bilby', 'RashersTierney', 'ResignBen16'}
# {'Rrius', 'Off2riorob'}
# {'Rrius', 'Off2riorob'}
# {'Freakshownerd', 'WLU', 'Rd232', 'K. Hausen Maem'}
# {'Spartaz', 'Freakshownerd'}
# {'UrbanNerd', 'Ckatz', 'Skookum1', 'PKT'}
# {'UrbanNerd', 'Miesianiacal', 'GoodDay', 'BilCat', 'Resolute'}
# {'72.184.129.252', 'Ryulong'}
# {'72.184.129.252', 'Ryulong'}
# {'Commodore Sloat', 'MONGO', 'RonCram'}
# {'Commodore Sloat', 'Anthonymendoza', 'RonCram'}
# {'Kafziel', 'Friday'}
# {'LCIstudent', 'Friday'}
# {'AuthorityTam', 'Jeffro77', 'Jimmy Pitt'}
# {'Jimmy Pitt', 'Good Olfactory'}
# {'Hzh', 'Mlpearc'}
# {'Hzh', 'EnDaLeCoMpLeX'}
# {'Friday', 'WestJet'}
# {'Raven Symone', 'Cute 1 4 u', 'Nakon', 'WestJet'}
# {'Favonian', 'Optimist on the run', 'Tmhm'}
# {'Walter Görlitz', 'Ronhjones', 'Tmhm', 'Tbhotch', 'Cplakidas', 'Kww'}
# {'Richmond96', 'Pats1', 'Chrisjnelson'}
# {'Pats1', 'Chrisjnelson'}
# {'Protector of Wiki', 'UncleDouggie', 'Courcelles'}
# {'Protector of Wiki', 'Courcelles'}
# {'Millahnna', 'Jéské Couriano', 'Off2riorob', 'Bbb23', 'Ocaasi', 'CycloneGU', 'PL290'}
# {'Jéské Couriano', 'Off2riorob'}
# {'Jaakobou', 'PalestineRemembered', 'Nadav1'}
# {'Agha Nader', 'Aschoeff'}
# {'5theye', 'Twsx'}
# {'5theye', '92.21.144.42', 'Rehevkor'}
# {'GiantSnowman', 'TwistOfCain'}
# {'Dylan Flaherty', 'TwistOfCain'}
# {'219.73.34.22', 'Brianlo747', 'Nakon'}
# {'Andy Handy Smurf', 'Betsythedevine', 'Nakon'}
# {'SMasters', 'Mgiganteus1', 'Cwmhiraeth'}
# {'Ironholds', 'Cwmhiraeth'}
# {'Dbachmann', 'Khirurg', '71.198.103.119'}
# {'Aigest', 'Megistias'}
# {'Timmeh', 'Rlevse'}
# {'Rlevse', 'Gadget850'}
# {'Kingjeff', 'ZH2010'}
# {'Kingjeff', 'ZH2010'}
# {'Soap', 'Cunard', 'Nakon'}
# {'CsprBzmr', 'Nakon'}
# {'Will Beback', 'Orangemarlin'}
# {'Orangemarlin', 'AshforkAZ'}
# {'Gritzko', 'Ssr', 'Bbb23'}
# {'Gritzko', 'Ssr', '2A02:6B8:0:107:D83D:EE04:EA8D:1553'}
# {'TaerkastUA', 'VKFP'}
# {'Acroterion', 'TaerkastUA', 'VKFP'}
# {'AussieLegend', 'Dcupdates11'}
# {'AussieLegend', 'Dcupdates11', 'Kww'}
# {'Solntsa90', 'All Rows4'}
# {'All Rows4', 'Sean.hoyland'}
# {'Crazymonkey1123 public', 'PTJoshua', 'Awawawawoo'}
# {'Mfon2', 'Errantacademic', 'PTJoshua'}
# {'Kirukp', 'PrimeHunter'}
# {'Dharmadhyaksha', 'Msrag', 'Jionpedia', 'Ayanosh'}
# {'Theroadislong', 'Blackberry Sorbet', 'Fluffernutter'}
# {'Blackberry Sorbet', 'GiantSnowman'}
# {'Любослов Езыкин', 'Anupam', '94.208.193.73'}
# {'Любослов Езыкин', 'IlikePie132'}
# {'Dr. Blofeld', '86.151.246.207', 'Bishonen'}
# {'217.57.3.98', 'Dr. Blofeld', 'Rizzardi'}
# {'ColonelHenry', 'SummerPhD'}
# {'ColonelHenry', 'SummerPhD'}
# {'DragonKing22', 'Sergecross73'}
# {'DragonKing22', 'Trivialist'}
# {'Evilbu', 'Liberlogos'}
# {'Mathieugp', '70.49.240.232'}
# {'Maunus', 'Leadwind'}
# {'87.79.119.75', 'Maunus'}
# {'DangerousPanda', 'Psychonaut', 'Aimperator', 'Bishonen'}
# {'Betty Logan', 'Mark Arsten', 'Aimperator'}
# {'Ed Poor', 'Simesa'}
# {'Gabrielsimon', 'Adam Carr'}
# {'GDK', 'Shelbystripes', 'MattChatt18'}
# {'YSSYguy', 'WilliamJE', 'Shelbystripes'}
# {'Ssilvers', 'Nrswanson', 'Folantin'}
# {'Johnbod', 'Kleinzach'}
# {'Saul Grant', 'SummerPhDv2.0'}
# {'Flyer22 Reborn', 'EdJohnston', 'Saul Grant'}
# {'207.237.223.150', 'Pazuzu567', '64.191.211.54'}
# {'Hotwiki', 'Kasreyn', 'Wallie'}
# {'Psyphics', 'Phoenix741', 'Nick Begovich', 'FixerMX', 'Mrph', 'Tenebrae', 'Doczilla'}
# {'72.83.123.247', 'Tenebrae', 'Larry laptop', 'Bloodpack'}
# {'Zeizmic', 'Ryanjo', 'SagaraSousuke'}
# {'Jfg284', '72.1.217.228'}
# {'Hyst', 'Sherurcij', 'FiveParadox', 'Digging.holes~enwiki'}
# {'Capsela', 'SFrank85'}
# {'Anarchistdy', 'GSK'}
# {'Anarchistdy', 'GSK'}
# {'Tyau123', 'Murry1975'}
# {'JMHamo', 'Tyau123', 'Mattythewhite'}
# {'Whiskey Rebellion', 'Blockader'}
# {'AaronS', 'MrVoluntarist'}
# {'JJMC89', 'Black Yodel No.1', 'Timtrent'}
# {'Black Yodel No.1', 'Timtrent'}
# {'ScifiterX', 'Hiding', '68.207.112.39'}
# {'SoM', 'Nightscream', 'ScifiterX'}
# {'74.83.68.15', 'Tide rolls'}
# {'JamesBWatson', 'Prodigy 16'}
# {'Wolfkeeper', 'Dank'}
# {'Wolfkeeper', 'Brewhaha@edmc.net'}
# {'DPL bot', 'Wilshica', 'Sciencewatcher'}
# {'Sciencewatcher', 'The Jolly Bard'}
# {'75.75.116.254', 'Coffee'}
# {'Eaaeaaster Raand', 'Coffee'}
# {'Abjiklam', 'Huon', 'Helmoony'}
# {'Tounsimentounes', 'Jeppiz'}
# {'Mrninja13', '203.219.182.64', '203.213.17.245', 'Davhorn', 'CyberGhostface'}
# {'GSK', '123.211.49.147', 'Nesiac'}
# {'Kraxler', 'SMcCandlish', 'Czoal'}
# {'Montanabw', 'Czoal'}
# {'GB fan', 'ALongStay'}
# {'2607:FB90:2407:5704:B64C:A245:8313:1F21', 'ALongStay'}
# {'Saff V.', 'Toddy1', 'HyperGaruda', 'Mhhossein'}
# {'Saff V.', 'FreeatlastChitchat'}
# {'D.R Neal G', 'GeneralizationsAreBad'}
# {'JJMC89', 'D.R Neal G', 'GeneralizationsAreBad'}
# {'Nightstallion', '209.7.171.66', 'Man vyi', '213.189.176.51', 'LonghornJohnny'}
# {'Nightstallion', '213.164.241.16'}
# {'Wendtrut', 'Casliber'}
# {'Hesperian', 'Casliber'}
# {'Rdsmith4', 'Oskar Sigvardsson', 'Sundar', 'Alexwcovington', 'Dismas', 'Canderson7', 'BaronLarf', 'Pharos'}
# {'PFHLai', 'Pharos', 'Gozar'}
# {'Rettetast', 'A7x', 'Garion96'}
# {'Hunter Kahn', 'A7x', 'CTF83!'}
# {'Tooga', 'Krm500'}
# {'Freshfighter9', 'Krm500'}
# {'Mick gold', 'Ceoil', 'Gerda Arendt'}
# {'Tom harrison', 'Ceoil'}
# {'Outriggr', 'Modernist', 'Ceoil'}
# {'John', 'Ceoil'}
# {'Peter I. Vardy', 'Senra', 'SandyGeorgia', 'Malleus Fatuorum'}
# {'Risker', 'Moni3', 'Malleus Fatuorum'}
# {'Malleus Fatuorum', 'Richerman'}
# {'Malleus Fatuorum', 'Balph Eubank'}
# {'Rodw', 'Malleus Fatuorum'}
# {'Sky Attacker', 'Malleus Fatuorum'}
# {'PS2pcGAMER', 'OrphanBot', 'Hganesan'}
# {'203.214.88.244', 'PS2pcGAMER', 'Hganesan'}
# {'Caribbean H.Q.', 'Thejadefalcon', 'Spitfire', 'Technogreek43'}
# {'Technogreek43', '7'}
# {'205.189.150.1', 'Bearcat', 'Ground Zero', 'Zazaban'}
# {'Bearcat', 'Mindmatrix', 'Ravedave'}
# {'Tsunami Butler', 'Ideogram'}
# {'Badagnani', 'Ideogram'}
# {'Linas', 'Rkitko'}
# {'Jpod2', 'FF2010', 'Linas'}
# {'Pinkbeast', 'Happysailor', 'Jacurani'}
# {'Jacurani', 'Widr', 'Happysailor'}
# {'Carfiend', 'Ikanreed'}
# {'Numskll', 'Carfiend'}
# {'Geo Swan', 'Luna Santin'}
# {'Luna Santin', 'Dyinghappy', 'RaNdOm26'}
# {'Matt57', 'Itaqallah', 'Arrow740'}
# {'Giordaano', 'Jonnyk1982', 'Itaqallah'}
# {'Djegan', 'Emir214'}
# {'Djegan', 'Factoid Killer'}
# {'MichaelQSchmidt', 'SummerPhD'}
# {'SummerPhD', 'Drmies'}
# {'63.163.213.249', 'SarekOfVulcan'}
# {'Nomoskedasticity', 'Cirt', 'Off2riorob'}
# {'The Four Deuces', 'K', 'LegitimateAndEvenCompelling'}
# {'PAVA11', 'LegitimateAndEvenCompelling'}
# {'Victoriaearle', 'Modernist'}
# {'Victoriaearle', 'Modernist'}
# {'Dwanyewest', 'JIP', 'Mathewignash', 'Skinny87'}
# {'Dwanyewest', 'Mathewignash'}
# {'MaxSem', 'Nik42'}
# {'Squidd', 'Kingturtle', '68.198.190.31'}
# {'Sofffie7', 'Willthacheerleader18', '207.161.130.133'}
# {'Threeafterthree', 'Jacksonori47'}
# {'Maxburgoyne', 'Justkindness', 'ChrisJB', '212.219.105.21'}
# {'CrossHouses', 'Simple Bob', 'Dpaajones', 'SalopianJames'}
# {'Valrith', 'Kolindigo'}
# {'Valrith', 'Bastique', 'Cbrown1023'}
# {'Ernest the Sheep', 'Matty', 'Wallie'}
# {'Ernest the Sheep', 'Matty', 'Wallie'}
# {'170.215.197.36', 'HJensen', 'Mickraus'}
# {'Zabrak', 'Anger22'}
# {'Sarah777', 'RashersTierney'}
# {'BigDunc', 'Sarah777', 'Jeanne boleyn'}
# {'Astronautics~enwiki', 'MARMOT'}
# {'Astronautics~enwiki', 'Barry Wells'}
# {'Stephan Schulz', 'Vsmith', 'Emperor001', 'Rewinn'}
# {'KimDabelsteinPetersen', 'Nathan Johnson', 'Q Science', 'GoRight'}
# {'Threeafterthree', 'Nssdfdsfds', 'DWaterson', '62.136.238.65', 'Pogsurf'}
# {'62.136.238.65', 'Nssdfdsfds', 'Pogsurf'}
# {'MarmadukePercy', 'JNW'}
# {'Nineteen Nightmares', 'JNW'}
# {'Chrislk02', 'Arcayne'}
# {'Wrestlinglover420', 'Chrislk02', 'Sesshomaru'}
# {'Calton', 'Captainktainer', 'MSTCrow'}
# {'Oiboy77', 'MSTCrow'}
# {'Sherzo', 'JMalky'}
# {'Sherzo', 'JMalky', 'Wongch2', '82.26.105.210'}
# {'Winhunter', 'CelebHeights'}
# {'DXRAW', 'Halbared'}
# {'Ludde23', 'Not a dog'}
# {'Crunch', 'Not a dog'}
# {'Nathan Johnson', '2over0', 'William M. Connolley', 'Pelarmian', 'BozMo'}
# {'Unitanode', 'William M. Connolley'}
# {'Rosencomet', 'Viriditas', 'Mattisse'}
# {'Rosencomet', 'Ohconfucius', 'Mattisse'}
# {'Mamalujo', 'Mangostar', 'Giraffedata'}
# {'Magidin', 'Giraffedata'}
# {'OsamaK', 'Ww2censor'}
# {'Tedder', 'Ww2censor'}
# {'Peteforsyth', 'Benjiboi'}
# {'Steven Walling', 'Benjiboi'}
# {'The Four Deuces', 'Introman', 'Delirium'}
# {'Slizor', '71.15.117.251'}
# {'Da Main Event', 'Nahallac Silverwinds', 'Bcarlson33'}
# {'Katiedid', 'Miwasatoshi'}
# {'Instantnood', 'Huaiwei'}
# {'Instantnood', 'Huaiwei'}
# {'Syrthiss', 'EFG'}
# {'Syrthiss', 'Steel'}
# {'Accedie', 'Philippe (WMF)', 'FisherQueen'}
# {'Ipv6man', 'FisherQueen'}
# {'FisherQueen', 'Jeffpw'}
# {'Bofo08', 'Ioeth', 'FisherQueen'}
# {'Kww', 'Agent999', '190.142.58.125'}
# {'TBDT', 'Ward3001', 'Gifttooffer', 'MLP1993'}
# {'Dream Focus', 'Pablo X'}
# {'Dream Focus', 'Maelgwnbot', 'NocturneNoir'}
# {'LaidOff', 'Aunt Entropy', 'Jros83'}
# {'Joshuaingram', 'Jros83'}
# {'.mdk.', 'Jtalledo', '69.113.230.141'}
# {'Fr3nZi3', '69.113.230.141'}
# {'Kappa', 'Agüeybaná'}
# {'Kappa', 'Agüeybaná'}
# {'Pinkadelica', 'AJona1992'}
# {'Jeffro77', 'AJona1992'}
# {'Awsguy1', 'Coaster1983', 'Arzel'}
# {'CPO Pieman', 'Plasma Twa 2'}
# {'Babelfisch', 'Nat Krause'}
# {'Babelfisch', 'Luna Santin'}
# {'Kwamikagami', 'West Bank Boy'}
# {'Jingiby', '3rdAlcove', 'Laveol', 'MacedonianBoy'}
# {'RedSpruce', 'Cubdriver'}
# {'RedSpruce', '67.190.113.165'}
# {'Renenarciso', 'Ace Class Shadow', 'Primogen'}
# {'Dposse', 'Ace Class Shadow', 'DJ Chair'}
# {'Ganeshk', 'Elalan', 'Sechzehn'}
# {'Sudharsansn', 'Iwazaki'}
# {'Stew jones', 'DJhinckley', 'STBotI'}
# {'Stew jones', 'Robwingfield'}
# {'Spleodrach', 'Pldms'}
# {'Lapsed Pacifist', 'Spleodrach'}
# {'AndyTheGrump', 'Mr Bill Truth', 'CorbieVreccan'}
# {'Prokaryotes', 'Alexbrn'}
# {'Davidbspalding', 'Safemariner'}
# {'Kjoonlee', 'Davidbspalding', 'Oden', 'Petegrk'}
# {'Yamagishi', 'Atlan'}
# {'Pekin Republican', 'Atlan'}
# {'Deskana', 'Sasaki'}
# {'GroovySandwich', 'Big foot123456789'}
# {'KnowledgeOfSelf', 'Kim Bruning'}
# {'Lar', 'Kyorosuke', 'TheKMan'}
# {'Giants27', 'Pats1', 'Chrisjnelson'}
# {'Bender235', 'Giants27', 'Chrisjnelson'}
# {'Zachkudrna18@yahoo.com', 'Jesus On Wheels', 'Anouymous'}
# {'New Age Retro Hippie', 'Locke Cole'}
# {'JeffJ', 'Geeky Randy', '24.233.213.47'}
# {'JeffJ', 'BrendanFrye'}
# {'WJBscribe', 'Dev920'}
# {'THUGCHILDz', 'WJBscribe', 'Wahkeenah'}
# {'Mabalu', '83d40m'}
# {'83d40m', 'Phalanxpursos', 'Wetman'}
# {'Cirt', 'Misza13', 'RichardF'}
# {'RichardF', 'Michael Hardy'}
# {'Antaeus Feldspar', 'JimmyT'}
# {'9SGjOSfyHJaQVsEmy9NS', 'Terryeo'}
# {'JackHGD', 'Theroadislong'}
# {'Theroadislong', 'Johnn yCome Early', 'Andy Dingley'}
# {'Gene Nygaard', 'Jimp', 'Stepho-wrs', 'Twas Now', 'Huntster', 'Wikid77'}
# {'Gene Nygaard', 'Ohms law'}
# {'Dbachmann', 'Avedeus'}
# {'Dbachmann', 'Cuchullain', 'Reddi'}
# {'TriCheeseSorrow', 'Sesshomaru'}
# {'VorangorTheDemon', 'Sesshomaru'}
# {'24.247.120.42', 'TJ Spyke', '76.116.57.122'}
# {'TJ Spyke', 'Wrestlinglover', '69.248.229.206', 'NiciVampireHeart', 'Bam63126'}
# {'Iridescent', 'MZMcBride'}
# {'Iridescent', 'MZMcBride', 'Malleus Fatuorum'}
# {'Iridescent', 'Karanacs'}
# {'Iridescent', 'Malleus Fatuorum', 'Ealdgyth'}
# {'NawlinWiki', 'DYKUpdateBot', 'SineBot'}
# {'Zozo2kx', 'Mbz1', 'Huldra'}
# {'DavidWBrooks', 'Isaac Crumm', 'Wahkeenah', '88.111.1.148'}
# {'DavidWBrooks', 'Mr Richardson', 'Captain Infinity', 'Liverpool Scouse'}
# {'Canterbury Tail', 'Domer48', 'GoodDay', 'Sandstein'}
# {'LevenBoy', 'Canterbury Tail', 'Footyfanatic3000', 'HighKing'}
# {'BenBurch', 'Gordongekko909'}
# {'BenBurch', 'Gordongekko909'}
# {'No more bongos', 'Gscshoyru', 'Jeffpw'}
# {'Gscshoyru', 'Ilovebirtbikes'}
# {'Capricorn42', 'Alansohn', 'Pigsonthewing', 'Alexf', 'DinoBot2'}
# {'Beetstra', 'Gilliam'}
# {'Neutralhomer', 'Seb az86556'}
# {'Eric0889', 'Seb az86556'}
# {'HuskyHuskie', 'Koavf', 'Zaian', 'Vanished user 342562', 'Jonny-mt'}
# {'Orion11M87', 'HuskyHuskie', 'Abog'}
# {'Alex G', 'RaNdOm26'}
# {'Florrie', 'Gwinva', 'Illyria05', 'Mel Etitis'}
# {'Caniago', '64.128.85.2', 'MetsFan76'}
# {'SEWilco', 'AndersFeder', 'Scott'}
# {'Peter Damian', 'Skomorokh'}
# {'TheOldJacobite', 'Skomorokh'}
# {'Natalie Erin', 'Tesscass'}
# {'Natalie Erin', 'Nonononono~enwiki'}
# {'Kungfuadam', 'Tawkerbot2', 'Tangotango', 'WikiLeon'}
# {'Essjay', 'Bookofjude', 'Gwernol', '193.39.158.195', 'Ian Spackman', 'PizzaMargherita', 'Tawkerbot2'}
# {'195.195.0.77', 'TJ Spyke', 'Gavyn Sykes', 'Mr monday night'}
# {'Tj terrorible1', 'Big Boss 0', 'Bmg916'}
# {'Chensiyuan', 'Cumulus Clouds'}
# {'Chensiyuan', 'Brave warrior'}
# {'Essjay', 'FF2010'}
# {'Essjay', 'Kyle Barbour'}
# {'71.104.184.11', 'Kuru', 'Jpgordon', 'Crazymonkey1123'}
# {'Cube lurker', 'Jpgordon'}
# {'Scheinwerfermann', 'JimScott', '91.157.12.243', 'Wtshymanski'}
# {'Scheinwerfermann', 'Cantaloupe2', 'M0rphzone'}
# {'No such user', 'Walnuts go kapow'}
# {'Tamfang', 'Armbrust'}
# {'Peter Gulutzan', 'DHeyward', 'Mann jess', 'Shock Brigade Harvester Boris'}
# {'L235', 'MONGO', 'DHeyward'}
# {'Trovatore', 'Oleg Alexandrov'}
# {'Jtdirl', 'Trovatore'}
# {'Mercster', 'CT Cooper'}
# {'Mercster', 'CT Cooper'}
# {'Itsmejudith', 'Emmanuelm'}
# {'Itsmejudith', 'Emmanuelm'}
# {'DangerousPanda', 'Metallurgist'}
# {'Jehochman', 'Betty Logan'}
# {'ESkog', 'FARVA'}
# {'JDoorjam', 'FARVA'}
# {'Nmate', 'Tankred', 'MarkBA~enwiki', '88.209.210.153'}
# {'Tankred', '84.236.89.208', 'VinceB', 'Heavypiece'}
# {'Black Kite', 'Objective3000', 'Freakmighty'}
# {'Viriditas', 'Objective3000', 'Andyvphil'}
# {'Persian Poet Gal', 'Hipocrite'}
# {'Italiavivi', 'Hipocrite'}
# {'Amarrg', 'Dineshkannambadi'}
# {'Gnanapiti', 'Universal Hero'}
# {'Wfgh66', 'Wednesday Next'}
# {'Wfgh66', 'Wednesday Next'}
# {'64.142.102.94', 'Axiomatica'}
# {'Kevin', 'Peter G Werner', 'Axiomatica'}
# {'DrKay', 'DeCausa'}
# {'DrKay', 'KreanMek'}
# {'09aidepikiw', 'Bill', 'Borat55'}
# {'09aidepikiw', 'Borat55'}
# {'Gnip', 'PericlesofAthens'}
# {'Flamarande', 'Fullstop'}
# {'Somaliwarrior', 'Middayexpress'}
# {'Norwegianguy', 'Middayexpress'}
# {'IZAK', 'Yoninah', 'TShilo12'}
# {'IZAK', 'TShilo12'}
# {'TomPointTwo', 'Viriditas', 'Killing Vector'}
# {'DougRWms', 'Dman727', 'Turtlescrubber'}
# {'SelfTitledAlbum', 'Supasta', 'Lostinube', 'Xterra1'}
# {'KennyMan666', 'SelfTitledAlbum', 'Moozooh', 'Xterra1'}
# {'Erachima', 'Unician', 'TheFarix'}
# {'TheFarix', 'NeonPuffin'}
# {'Kozuch', 'Gimmetrow'}
# {'Kozuch', 'Wikidea'}
# {'PinoyFilAmPride', 'IQfur01'}
# {'Wikiscribe', 'Wtmitchell'}
# {'Nsk92', 'Trust Is All You Need'}
# {'MUCHERS22', 'Nsk92'}
# {'Khvalamde', 'Zzaffuto118'}
# {'Khvalamde', 'Dave1185'}
# {'Dahliarose', 'WhatamIdoing', 'John'}
# {'WhatamIdoing', 'Charlesdrakew'}
# {'Particled', '88.104.21.45', 'Millahnna', 'IllaZilla'}
# {'GDallimore', 'Polisher of Cobwebs', 'IllaZilla'}
# {'JGG', 'ThePromenader'}
# {'Hardouin', 'ThePromenader'}
# {'Heyitspeter', 'Scjessey'}
# {'Heyitspeter', 'Hipocrite'}
# {'Toddst1', 'Lorelorelore', 'O Fenian'}
# {'O Fenian', 'LessHeard vanU'}
# {'Zigzig20s', 'Stephen'}
# {'Beyond My Ken', 'Stephen'}
# {'Equazcion', 'Kim Dent-Brown'}
# {'Equazcion', 'Carcharoth', 'Ryan Postlethwaite'}
# {'TGCP', 'Brad101'}
# {'Varlaam', 'Barek'}
# {'Vcnez2017', 'Bakasuprman'}
# {'Sundaram7', 'Bakasuprman'}
# {'Shadow1', 'Radagast83', 'Lucy-marie', 'Jtrost'}
# {'Radagast83', 'Mathew5000', 'Lucy-marie', '131.96.14.78'}
# {'Viriditas', 'Damiens.rf'}
# {'Damiens.rf', 'SarekOfVulcan'}
# {'Yqbd', 'ConfuciusOrnis'}
# {'ConfuciusOrnis', 'ZayZayEM'}
# {'I luv erky', '202.57.75.237'}
# {'Kaiwhakahaere', 'PageantUpdater'}
# {'Mrt3366', 'MiszaBot I', 'Dalilida'}
# {'Darkness Shines', 'Killbillsbrowser', 'Mrt3366'}
# {'Geo Swan', 'Netscott'}
# {'GRuban', 'Xed'}
# {'The Gerg', 'Funnybunny'}
# {'The Gerg', 'Funnybunny'}
# {'Beyond My Ken', 'Bjenks'}
# {'Nixin06', 'Beyond My Ken'}
# {'Jinxmchue', 'Derex', 'DHeyward'}
# {'Scribner', 'Derex', 'Aaron'}
# {'66.99.2.114', 'MKil', 'Wompa99'}
# {'BoxingWear', 'MKil', '58.64.103.227'}
# {'Uyvsdi', 'Philkon', 'Vizjim'}
# {'Amerindianarts', 'Vizjim', 'Maziotis'}
# {'Falcon9x5', 'Remitroamer'}
# {'Tvensky', 'Falcon9x5'}
# {'CaptainVindaloo', 'Doc Tropics'}
# {'Doc Tropics', 'Orangemarlin'}
# {'Ryulong', 'Moscow Connection'}
# {'Ryulong', 'Moscow Connection'}
# {'U-Mos', 'EmeZxX'}
# {'Childzy', 'U-Mos'}
# {'EdJogg', 'FelixCheng', 'Penrithguy', 'Gwernol'}
# {'AmosWolfe', 'FelixCheng', 'Penrithguy', '84.64.49.83'}
# {'Thegreyanomaly', 'Dark Tea'}
# {'Corticopia', 'Dark Tea'}
# {'B-bot', 'Eric-1555', 'Davidbspalding'}
# {'Kjoonlee', 'Davidbspalding', 'Oden', 'Petegrk'}
# {'Merbabu', 'Hmains'}
# {'Chinasort', 'Dekisugi'}
# {'Alirobe', 'Latifa Raafat'}
# {'Ms Sarah Welch', 'SiddharthSunny'}
# {'70.53.92.156', 'Lycurgus', 'Taroaldo'}
# {'Lycurgus', 'Arch dude'}
# {'Arniep', 'Caltrop'}
# {'DreamGuy', 'Caltrop'}
# {'B', 'Nishkid64'}
# {'Bstevens760', 'B'}
# {'Dubc0724', 'DukeEgr93'}
# {'Duke53', 'Dubc0724'}
# {'T.Neo', 'Kizor'}
# {'T.Neo', 'MBisanz'}
# {'Sarah777', '92.1.226.235', 'Spleodrach'}
# {'Daniel Case', 'Spleodrach', '78.16.140.2'}
# {'MrJanitor1', '999mal', 'Cain Mosni'}
# {'Hans Adler', 'BillJohnson0003', 'Kintetsubuffalo'}
# {'Amoruso', 'Huldra'}
# {'Amoruso', 'Desertsky85451'}
# {'Scolaire', 'Paine Ellsworth'}
# {'JamesBay', 'Trust Is All You Need'}
# {'Pizzahut2', 'MastaFighta'}
# {'Huo Ma Ke', 'Marasmusine'}
# {'Kauffner', 'Gerda Arendt'}
# {'Ryulong', 'Kauffner'}
# {'Roslagen', 'Bjmullan', 'Bretonbanquet'}
# {'Falcadore', 'Roslagen', 'The359'}
# {'157.228.x.x', 'BalkanFever'}
# {'ΚΕΚΡΩΨ', 'PMK1'}
# {'CarrieVS', 'North8000', 'S Marshall'}
# {"The Devil's Advocate", 'Pablo X', 'S Marshall'}
# {'CircafuciX', 'Weltanschaunng', 'Blackmetalbaz', 'Navnløs'}
# {'CircafuciX', 'METALFREAK04', 'Weltanschaunng', 'Inhumer'}
# {'Tibbydibby', 'Random86'}
# {'Mikepellerin', 'Shinyang-i'}
# {'HandThatFeeds', 'Wesley Wolf'}
# {"The Devil's Advocate", 'HandThatFeeds'}
# {'Heyitspeter', 'Hipocrite', '134.10.124.232'}
# {'Tanthalas39', 'PennySeven', 'DarknessShines2'}
# {'EdJohnston', 'Mendaliv'}
# {'Renamed user 8gzkdu68phsoyd2', 'Jytdog'}
# {'Duffbeerforme', 'Perryglasser'}
# {'Duffbeerforme', 'Calvin999'}
# {'Future Perfect at Sunrise', 'SilentResident'}
# {'Future Perfect at Sunrise', 'SilentResident'}
# {'Kraken7', 'DagosNavy'}
# {'Kraken7', 'DagosNavy'}
# {'Tothwolf', 'Dusti'}
# {'Enigmaman', 'Dusti'}
# {'Kotiwalo', 'Ingowart'}
# {'Kotiwalo', 'Denpap'}
# {'Bmedley Sutler', 'Crockspot'}
# {'Bmedley Sutler', 'Crockspot'}
# {'Bobthefish2', 'Lvhis'}
# {'Bobthefish2', 'Qwyrxian'}
# {'Stephan Schulz', 'Raul654', 'UBeR'}
# {'Skyemoor', 'UBeR', 'THF'}
# {'Drieakko', 'SFGiants'}
# {'Drieakko', 'Jommala'}
# {'Jonas Poole', 'FisherQueen'}
# {'DangerousPanda', 'Jonas Poole'}
# {'とある白い猫', 'Lexi Marie', 'Causa sui'}
# {'Eclecticology', 'とある白い猫'}
# {'OpenFuture', 'LtPowers', 'Cybercobra'}
# {'Hypnosifl', 'Viriditas', 'Earl King Jr.'}
# {'MPLX', 'Gene Poole'}
# {'UninvitedCompany', 'MPLX'}
# {'Fractyl', 'Ryulong'}
# {'Floria L', 'Yaguruma'}
# {'Raj2004', 'Rudrasharman'}
# {'Raj2004', 'Rudrasharman'}
# {'Squiggleslash', 'Nbahn'}
# {'Yendor1152', 'Squiggleslash'}
# {'Brian', 'Hawkestone'}
# {'Hawkestone', 'Atlan'}
# {'Tarl N.', 'Cminard'}
# {'Loriendrew', 'Cminard'}
# {'Wrestlinglover', 'JakeDHS07', 'Vjmlhds'}
# {'Wrestlinglover', 'Hot Stuff International', '121.215.191.78'}
# {'Dr. Blofeld', 'FT2', 'AzaToth'}
# {'Giano II', 'Geogre', 'AzaToth'}
# {'Meneerke bloem', 'Rivertorch'}
# {'Podruznik', 'Rivertorch'}
# {'Matthew', 'Otto4711'}
# {'Otto4711', 'Henry Flower'}
# {'Captain scarlet', 'Optimist on the run'}
# {'Captain scarlet', 'Lewisskinner'}
# {'Woodstone', 'Chris55'}
# {'Jc3s5h', 'Gkell1'}
# {'CO', 'Nakon'}
# {'Blok off', 'Nakon'}
# {'McCart42', 'Rami R'}
# {'Rami R', 'JLMadrigal'}
# {'PocklingtonDan', 'Sopoforic'}
# {'LeanneMillington', 'PocklingtonDan'}
# {'Ian.thomson', 'Charlesdrakew', 'Jngf1'}
# {'SovalValtos', 'A P Monblat', 'Charlesdrakew'}
# {'Jaakobou', 'Eleland'}
# {'Jaakobou', 'N-HH'}
# {'Seraphim', 'Dlohcierekim'}
# {'Realkyhick', 'Applemac20'}
# {'Cirt', 'Coffeepusher'}
# {'Griswaldo', 'Coffeepusher'}
# {'TracyMcClark', 'Climate surfer 23', 'DarknessShines2', 'William M. Connolley'}
# {'BLPWatchdog', '174.34.174.4', 'William M. Connolley'}
# {'TheSickBehemoth', 'Bbb23'}
# {'Dan56', 'TheSickBehemoth'}
# {'Parrot of Doom', 'Malleus Fatuorum'}
# {'Parrot of Doom', 'Off2riorob'}
# {'DatDoo', 'Pedro'}
# {'Wknight94', 'DatDoo'}
# {'Fences and windows', 'Frank'}
# {'RMc', 'Frank'}
# {'Gunmetal Angel', 'MrMoustacheMM'}
# {'Cntras', 'Gunmetal Angel'}
# {'Deeceevoice', 'Wiki Raja', 'YellowMonkey'}
# {'KNM', 'Wiki Raja', 'Ryan Postlethwaite'}
# {'Jhenderson777', 'Harry Blue5'}
# {'Ryulong', 'Heavydata'}
# {'Rjd0060', 'Cheeser1'}
# {'Cedars', 'Cheeser1'}
# {'HkCaGu', 'ZHoover123'}
# {'HkCaGu', 'ZHoover123'}
# {'Polly', '137.201.242.130'}
# {'Gons', 'Polly', 'Mcaa09'}
# {'FDJK001', 'Vsmith'}
# {'Dandtiks69', 'John from Idegon'}
# {'Networkboy', 'Syrthiss'}
# {'Router~enwiki', 'Towsonu2003~enwiki', 'Syrthiss'}
# {'Boing! said Zebedee', 'Parrot of Doom'}
# {'Freshfighter9', 'Parrot of Doom'}
# {'Skomorokh', 'Tony1'}
# {'Skomorokh', 'Malleus Fatuorum'}
# {'Carfiend', 'Ikanreed'}
# {'Numskll', 'Carfiend'}
# {'SusanLesch', 'CTF83!'}
# {'SusanLesch', 'Huik01'}
# {'Hipocrite', 'ClueBot III', 'Nsaa'}
# {'Sirwells', 'Hipocrite'}
# {'Thanatos666', 'Elizium23'}
# {'Thanatos666', 'Elizium23'}
# {'Leyasu', 'Daddy Kindsoul'}
# {'Leyasu', 'Daddy Kindsoul'}
# {'Blainster', 'Ewlyahoocom'}
# {'Ikip', 'Ewlyahoocom'}
# {'Knowledgekid87', 'Verso.Sciolto', 'TheFarix'}
# {'Ryulong', 'TheFarix'}
# {'Shirahadasha', 'Historian2', 'Crzrussian', 'Spike Wilbury'}
# {'Shirahadasha', 'Historian2', 'Daniel575', 'Spike Wilbury'}
# {'Imzadi1979', "Br'er Rabbit"}
# {'Imzadi1979', 'Kumioko'}
# {'OlYeller21', 'TheDethklokGuy', 'Hatredy'}
# {'TheDethklokGuy', 'Hatredy'}
# {'Mendaliv', 'Jarhaugin'}
# {'JCHeverly', 'Mendaliv'}
# {'Axem Titanium', 'Zenoseiya'}
# {'Axem Titanium', 'Zenoseiya'}
# {'Cebactokpatop', 'Fr Lev', 'Seminarist'}
# {'Allyne', 'Cebactokpatop', 'Seminarist'}
# {'Venuzza67', 'Dan56'}
# {'Dan56', 'Dumaka', 'Andrzejbanas'}
# {'ImNotRichImStillLyin', 'B'}
# {'ImNotRichImStillLyin', 'Tasc0'}
# {'Avalean', 'Dark verdant'}
# {'Rpgod2', 'AsSheFelliSmiled'}
# {'Matt57', 'Itaqallah', 'Arrow740'}
# {'Giordaano', 'Jonnyk1982', 'Itaqallah'}
# {'Iryna Harpy', 'Laszlo Panaflex'}
# {'Wee Curry Monster', 'Laszlo Panaflex'}
# {'Jackechambers', 'Fabrictramp'}
# {'Dusti', 'Fabrictramp'}
# {'Grundle2600', 'Loonymonkey'}
# {'Loonymonkey', 'Die4Dixie'}
# {'Keegan (WMF)', 'Resident Mario'}
# {'A21sauce', 'Keegan'}
# {'Duleray', 'Charlesdrakew'}
# {'Mathezar', 'Charlesdrakew'}
# {'The Founders Intent', 'PPdd'}
# {'Hammersoft', 'Ludwigs2'}
# {'144.132.216.253', 'JPD'}
# {'Afgtnk', 'HiLo48'}
# {'AdhunikaSarvajna', 'VanishedUserABC'}
# {'SuzanneOlsson', 'VanishedUserABC'}
# {'Nishidani', 'NSH001'}
# {'Nishidani', 'NSH002'}
# {'Howcheng', 'BlackCab'}
# {'115.188.178.77', 'BlackCab'}
# {'The JPS', 'Ninetyone'}
# {'Kierant', 'Ninetyone'}
# {'Wiki-star', 'Dragon Emperor', 'William M. Connolley'}
# {'Wiki-star', 'Papacha'}
# {'SlamDiego', 'Jimfbleak'}
# {'SlamDiego', 'JzG'}
# {'Scarian', 'Police,Mad,Jack', 'Ned Scott'}
# {'Jossi', 'Niteshift36', 'Steve Smith'}
# {'Duchamps comb', 'Buspar', 'Keilana'}
# {'Buspar', 'EVula', 'DragonflySixtyseven'}
# {'DrKay', 'Chris the speller'}
# {'DrKay', 'Number 57'}
# {'Cebactokpatop', 'Seminarist'}
# {'Cebactokpatop', 'Seminarist'}
# {'Chzz', 'Ohms law'}
# {'Ohms law', 'Rich Farmbrough'}
# {'S. Casaubon', 'Karst'}
# {'Ajax1995', 'FueguinoTonkonoff'}
# {'Editor2020', 'Gabby Merger'}
# {'Editor2020', 'Gabby Merger'}
# {'Sulfur', 'RFD'}
# {'Sulfur', 'Vanished user qijr1oincdj5tyhj34tinwd'}
# {'Regancy42', 'Moocha'}
# {'Moocha', 'Floggingmolly101'}
# {'Valrith', 'Tony Sidaway', 'MaxSem'}
# {'Valrith', 'Bastique', 'Cbrown1023'}
# {'Zero0000', 'Zeq'}
# {'Zero0000', 'Zeq'}
# {'JarrahTree', 'NobutoraTakeda', 'Thewinchester'}
# {'Isotope23', 'NobutoraTakeda'}
# {'Cuñado', 'General Disarray'}
# {'MARussellPESE', 'General Disarray'}
# {'Spanneraol', 'Justhangin'}
# {'Spanneraol', 'Videmus Omnia'}
# {'Robbstrd', 'Cryogenesis'}
# {'TheRedPenOfDoom', 'Robbstrd'}
# {'Scarian', '216.21.150.44'}
# {'216.21.150.44', 'Navnløs'}
# {'Spleodrach', 'Dornálaíocht'}
# {'J Milburn', 'Spleodrach'}
# {'IZAK', 'Ludvikus'}
# {'IZAK', 'Ludvikus'}
# {'Vranak', 'Anchoress'}
# {'Friday', 'Vranak'}
# {'Doug Weller', 'Jdforrester'}
# {'Justlettersandnumbers', 'Jdforrester'}
# {'McGeddon', 'X4n6', 'Ssilvers'}
# {'X4n6', 'WWGB', 'Adornix'}
# {'Hereward77', 'Srnec'}
# {'Hereward77', 'HanzoHattori'}
# {'Relax ull be ok', 'Sharnak'}
# {'Relax ull be ok', 'Baba Louis'}
# {'DrKay', 'Moonraker12'}
# {'DrKay', 'Alexcoldcasefan'}
# {'Big Bird', 'Xeno'}
# {'Big Bird', 'GriffinSB'}
# {'Migospia', 'Lsi john', 'K12worker'}
# {'Lsi john', 'Alison', 'Smee'}
# {'Kaldari', 'BrineStans', 'Huntster'}
# {'BrineStans', 'Doncram', 'Orlady'}
# {'Quadell', 'Silverback'}
# {'Timeshifter', 'Seigfried4220'}
# {'Afghana~enwiki', 'Giraffedata'}
# {'Magidin', 'Giraffedata'}
# {'OMEGA KIER', 'Jedisteve0001', 'Sarahj2107'}
# {'Kn5150', 'Sarahj2107'}
# {'Apostle12', 'Ling.Nut'}
# {'Ice Cold Beer', 'Apostle12'}
# {'TJ Spyke', 'Darrenhusted', 'Anakinjmt'}
# {'Tj terrorible1', 'Big Boss 0', 'Bmg916'}
# {'Plrk', 'Anna Frodesiak'}
# {'Plrk', 'Buzza69'}
# {'Ltwin', 'Rachida10z'}
# {'Mike Doughney', 'Manutdglory'}
# {'Reswobslc', 'Polarscribe'}
# {'Cool Hand Luke', 'Reswobslc'}
# {'Una Smith', 'AeronM', 'Montanabw'}
# {'Una Smith', 'Rlevse', 'Montanabw'}
# {'Kojozone', 'Arcayne'}
# {'Scythian77', 'Darkness Shines'}
# {'Afterwriting', 'SportsEditor518'}
# {'Afterwriting', 'SNUGGUMS'}
# {'Lookingthrough', 'Tweisbach', 'DAJF'}
# {'Yariau neko', 'Firithfenion', 'Hetelllies'}
# {'Wiki truth enlighten', 'Manning Bartlett'}
# {'Threeafterthree', 'Will Beback'}
# {'Lasallefan', 'NickelShoe'}
# {'Lasallefan', 'Durin'}
# {'SkyWalker', '203.212.52.35'}
# {'Cdaughertyjr', 'SkyWalker'}
# {'Jasonbres', 'Acps110'}
# {'AndyTheCop', 'Jasonbres'}
# {'DigitalC', 'InternetHero', '2over0'}
# {'Spanneraol', 'InternetHero', 'Xeno'}
# {'150.101.57.169', 'MiszaBot III', 'Looie496'}
# {'The Founders Intent', 'Looie496'}
# {'Magioladitis', 'Kwamikagami'}
# {'Addshore', 'Tagishsimon'}
# {'Kiac', 'Shaidar cuebiyar'}
# {'F-22 Raptored', 'Tedder'}
# {'Ufwuct', 'Kndimov'}
# {'Ufwuct', 'Petergriffin9901'}
# {'Tom harrison', 'PPGMD'}
# {'Morton devonshire', 'Tom harrison'}
# {'Biomedeng', 'Useless.miscellany', 'Amazingracer'}
# {'Kokayi', 'Biomedeng', 'Amazingracer'}
# {'Bluefish35', 'Ww2censor'}
# {'Factocop', 'Mo ainm'}
# {'Gunmetal Angel', 'F-22 Raptored'}
# {'Gunmetal Angel', 'Leitmotiv'}
# {'Tenebrous', 'ChrisO~enwiki', 'AxelBoldt'}
# {'JimmyT', 'ChrisO~enwiki', 'Fahrenheit451'}
# {'UrbanTerrorist', 'Scheinwerfermann'}
# {'UrbanTerrorist', 'Scheinwerfermann'}
# {'Laughing Man', 'HanzoHattori'}
# {'Laughing Man', 'HanzoHattori'}
# {'Commodore Sloat', 'Former user 2', 'Precis'}
# {'CSTAR', 'Commodore Sloat', 'Armon'}
# {'Readyseason', 'Hello Control'}
# {'Hello Control', 'Michig'}
# {'Justanother', 'Lsi john'}
# {'Lsi john', 'Baseball Bugs'}
# {'Rockpocket', 'Light current'}
# {'SCZenz', 'Light current'}
# {'Babakathy', 'Cliftonian'}
# {'Beneaththelandslide', 'Perspicacite'}
# {'Guillaume2303', 'Headbomb'}
# {'Miym', 'Abductive'}
# {'RasputinAXP', 'Darkaz'}
# {'RasputinAXP', 'AmericanDad86'}
# {'J Di', 'Jouvenel'}
# {'Publishing', 'J Di'}
# {'Coffeepusher', 'Ugog Nizdast'}
# {'Coffeepusher', 'Selmaflora294'}
# {'Yaf', 'The Deviant'}
# {'Cramz32', 'Dullfig'}
# {'Zoupan', 'F382d56d7a18630cf764a5b576ea1b4810467238'}
# {'Nemambrata', 'F382d56d7a18630cf764a5b576ea1b4810467238'}
# {'Geo Swan', 'BenAveling'}
# {'BenAveling', 'Duke53'}
# {'Derex', 'Kizzle'}
# {'Haizum', 'Derex'}
# {'Cryptic', 'Thivierr', 'Daycd'}
# {'Thivierr', 'Daycd', 'Theblacklarl'}
# {'JHunterJ', 'Linas'}
# {'Radiant!', 'Linas'}
# {'Luk', 'Tiddly Tom', 'SHOUT357437943'}
# {'Daniel Case', 'X!', 'SHOUT357437943'}
# {'TreasuryTag', 'Grundle2600'}
# {'Grundle2600', 'Scjessey'}
# {'Seregain', 'Aunt Entropy'}
# {'Gabr-el', 'Aunt Entropy'}
# {'Filll', 'Raspor', 'KillerChihuahua'}
# {'Ec5618', 'Raspor', 'FeloniousMonk'}

# %%
awry_corpus.get_conversations_dataframe()
# Out:
#                       vectors               meta.page_title meta.page_id  \
# id
# 146743638.12652.12652      []                User talk:2005      1003212
# 143890867.11926.11926      []                User talk:2005      1003212
# 127296808.516.516          []           User talk:Billzilla     10051321
# 144643838.1236.1236        []           User talk:Billzilla     10051321
# 66813686.23567.23567       []  Talk:Niger uranium forgeries      1005730
# ...                       ...                           ...          ...
# 278765498.27104.27104      []         User talk:Grundle2600     10902498
# 345472052.2707.2707        []        User talk:Aunt Entropy     15801810
# 236755381.13326.13326      []        User talk:Aunt Entropy     15801810
# 99357960.32952.32952       []              User talk:Raspor      8071956
# 98071983.10061.9817        []              User talk:Raspor      8071956
#
#                                 meta.pair_id  \
# id
# 146743638.12652.12652  143890867.11926.11926
# 143890867.11926.11926  146743638.12652.12652
# 127296808.516.516        144643838.1236.1236
# 144643838.1236.1236        127296808.516.516
# 66813686.23567.23567    68000691.25417.25417
# ...                                      ...
# 278765498.27104.27104  275409490.16844.16844
# 345472052.2707.2707    236755381.13326.13326
# 236755381.13326.13326    345472052.2707.2707
# 99357960.32952.32952     98071983.10061.9817
# 98071983.10061.9817     99357960.32952.32952
#
#                       meta.conversation_has_personal_attack meta.verified  \
# id
# 146743638.12652.12652                                 False          True
# 143890867.11926.11926                                  True          True
# 127296808.516.516                                     False          True
# 144643838.1236.1236                                    True          True
# 66813686.23567.23567                                  False          True
# ...                                                     ...           ...
# 278765498.27104.27104                                  True          True
# 345472052.2707.2707                                   False          True
# 236755381.13326.13326                                  True          True
# 99357960.32952.32952                                  False          True
# 98071983.10061.9817                                    True          True
#
#                       meta.pair_verified meta.annotation_year meta.split
# id
# 146743638.12652.12652               True                 2018      train
# 143890867.11926.11926               True                 2018      train
# 127296808.516.516                   True                 2018      train
# 144643838.1236.1236                 True                 2018      train
# 66813686.23567.23567                True                 2018      train
# ...                                  ...                  ...        ...
# 278765498.27104.27104               True                 2018      train
# 345472052.2707.2707                 True                 2018       test
# 236755381.13326.13326               True                 2018       test
# 99357960.32952.32952                True                 2018       test
# 98071983.10061.9817                 True                 2018       test
#
# [1168 rows x 9 columns]

# %%
utterances = awry_corpus.get_utterances_dataframe()

# %%
utterances.sample(10)
# Out:
#                          timestamp  \
# id
# 116610974.14189.14189  1.17442e+09
# 399183585.5117.5117    1.29088e+09
# 492928306.46993.46993   1.3372e+09
# 44899832.36398.36398     1.143e+09
# 24164771.13558.13558   1.12784e+09
# 521278464.7241.7241    1.35199e+09
# 270328244.28512.28512  1.23448e+09
# 321002856.2975.2975    1.25605e+09
# 286787641.8951.8951    1.24098e+09
# 658888428.902.902      1.42982e+09
#
#                                                                     text  \
# id
# 116610974.14189.14189  Hi Itaq, Do not vandalize content on Wikipedia...
# 399183585.5117.5117    **The article is on my watchlist, which is why...
# 492928306.46993.46993   Bullshit. Dahliarose has restored at least on...
# 44899832.36398.36398    You have just admited that you did this to ma...
# 24164771.13558.13558   This article is nothing but a bunch of 's opin...
# 521278464.7241.7241     The don't-intersperse-on-talk-pages policy is...
# 270328244.28512.28512  In this case it's not really about facts.. it'...
# 321002856.2975.2975    The whole thing needs to be removed per wiki_l...
# 286787641.8951.8951    I think this could be solved by saying that Ca...
# 658888428.902.902       There is something that heavily concerns me, ...
#
#                                 speaker               reply_to  \
# id
# 116610974.14189.14189         Giordaano  116605439.14082.14054
# 399183585.5117.5117       Baseball Bugs    399183053.4932.4932
# 492928306.46993.46993     Charlesdrakew  492927701.46914.46914
# 44899832.36398.36398                Zeq   44873805.36322.36322
# 24164771.13558.13558      Howrealisreal   23619937.12859.12924
# 521278464.7241.7241    Scheinwerfermann    521171825.6632.6632
# 270328244.28512.28512        Spanneraol  270311808.28417.28417
# 321002856.2975.2975            Benjiboi  320926790.13705.13705
# 286787641.8951.8951            Awickert    286761180.8636.8636
# 658888428.902.902            Dandtiks69      658888258.158.158
#
#                              conversation_id meta.is_section_header  \
# id
# 116610974.14189.14189  116605439.14054.14054                  False
# 399183585.5117.5117      399172725.4008.4008                  False
# 492928306.46993.46993  492922820.46400.46400                  False
# 44899832.36398.36398    44828642.35766.35766                  False
# 24164771.13558.13558    23619937.12859.12924                  False
# 521278464.7241.7241      521109525.5453.5453                  False
# 270328244.28512.28512  270177839.28034.28034                  False
# 321002856.2975.2975    320926675.13624.13460                  False
# 286787641.8951.8951      286761180.8636.8636                  False
# 658888428.902.902          658888258.158.158                  False
#
#                       meta.comment_has_personal_attack meta.toxicity  \
# id
# 116610974.14189.14189                            False      0.119089
# 399183585.5117.5117                              False      0.388942
# 492928306.46993.46993                             True      0.820106
# 44899832.36398.36398                             False      0.048639
# 24164771.13558.13558                              True      0.630584
# 521278464.7241.7241                              False      0.255673
# 270328244.28512.28512                            False     0.0339964
# 321002856.2975.2975                              False       0.30627
# 286787641.8951.8951                              False       0.11616
# 658888428.902.902                                False      0.111868
#
#                                                              meta.parsed
# id
# 116610974.14189.14189  [{'rt': 0, 'toks': [{'tok': 'Hi', 'tag': 'UH',...
# 399183585.5117.5117    [{'rt': 0, 'toks': [{'tok': '*', 'tag': 'NFP',...
# 492928306.46993.46993  [{'rt': 1, 'toks': [{'tok': ' ', 'tag': '', 'd...
# 44899832.36398.36398   [{'rt': 4, 'toks': [{'tok': ' ', 'tag': '', 'd...
# 24164771.13558.13558   [{'rt': 2, 'toks': [{'tok': 'This', 'tag': 'DT...
# 521278464.7241.7241    [{'rt': 12, 'toks': [{'tok': ' ', 'tag': '', '...
# 270328244.28512.28512  [{'rt': 13, 'toks': [{'tok': 'In', 'tag': 'IN'...
# 321002856.2975.2975    [{'rt': 3, 'toks': [{'tok': 'The', 'tag': 'DT'...
# 286787641.8951.8951    [{'rt': 1, 'toks': [{'tok': 'I', 'tag': 'PRP',...
# 658888428.902.902      [{'rt': 2, 'toks': [{'tok': ' ', 'tag': '', 'd...

# %%
"""
cnt = 0
for utt in awry_corpus.iter_utterances():
    cnt += 1
    print(ps.transform_utterance(utt))
    if cnt > 2:
        break
"""

# %% [markdown]
# #### Predict Politeness: Use wiki_corpus for training, then apply the classifier on awry_corpus to get the prediction score

# %%
# Downloading the wikipedia portion of annotated data
wiki_corpus = Corpus(download("wikipedia-politeness-corpus"))
# Out:
# Dataset already exists at C:\Users\Think\.convokit\downloads\wikipedia-politeness-corpus

# %%
wiki_corpus.print_summary_stats()
# Out:
# Number of Speakers: 1
# Number of Utterances: 4353
# Number of Conversations: 4353

# %%
ps = PolitenessStrategies()
awry_corpus = ps.transform(awry_corpus, markers=True)
wiki_corpus = ps.transform(wiki_corpus, markers=True)

# %%
test_ids = awry_corpus.get_utterance_ids()

# %%
train_corpus = Corpus(utterances=[utt for utt in wiki_corpus.iter_utterances()])
test_corpus = Corpus(utterances=[utt for utt in awry_corpus.iter_utterances()])
print("train size = {}, test size = {}".format(len(train_corpus.get_utterance_ids()),
                                               len(test_corpus.get_utterance_ids())))
# Out:
# train size = 4353, test size = 6363

# %%
clf = Classifier(obj_type="utterance", 
                        pred_feats=["politeness_strategies"], 
                        labeller=lambda utt: utt.meta['Binary'] == 1)
clf.fit(train_corpus)
# Out:
# Initialized default classification model (standard scaled logistic regression).

# %%
test_pred = clf.transform(test_corpus)

# %%
pred_df = clf.summarize(test_pred)
pred_df.head(20)
# Out:
#                        prediction  pred_score
# id
# 132662410.11977.11977           0    0.009742
# 410838569.61940.61940           0    0.019028
# 236161634.27143.27131           0    0.020131
# 444898053.3389.3389             0    0.020926
# 418695946.3459.3449             0    0.020926
# 36146600.3862.3862              0    0.021219
# 606915191.4713.4713             0    0.022217
# 408191172.17962.17962           0    0.022496
# 344941369.12789.12789           0    0.023541
# 123265296.5701.5701             0    0.024656
# 349271207.4653.4653             0    0.026663
# 219409911.27840.27840           0    0.027075
# 311233422.1261.1251             0    0.027358
# 91238339.9018.9018              0    0.027662
# 48223090.8116.8092              0    0.027662
# 335849428.5696.5696             0    0.027662
# 473839577.3080.3080             0    0.029251
# 36603478.9519.9519              0    0.029723
# 14286807.842.842                0    0.029723
# 744949047.2954.2940             0    0.029893

# %%
test_utters_df = test_corpus.get_utterances_dataframe()
test_utters_df.sample(3)
# Out:
#                         timestamp  \
# id
# 272953472.1207.1207    1.2355e+09
# 92960315.5680.5680    1.16562e+09
# 80105638.13140.13140  1.16026e+09
#
#                                                                    text  \
# id
# 272953472.1207.1207                == Could you have a look please ==\n
# 92960315.5680.5680                     \n== Do you delete this file? ==
# 80105638.13140.13140   I specified in talk. This article was just cr...
#
#                        speaker              reply_to       conversation_id  \
# id
# 272953472.1207.1207    BigDunc                  None   272953472.1207.1207
# 92960315.5680.5680    Jouvenel                  None    92960315.5680.5680
# 80105638.13140.13140   Amoruso  80104056.13083.13083  80103228.13014.13014
#
#                      meta.is_section_header meta.comment_has_personal_attack  \
# id
# 272953472.1207.1207                    True                            False
# 92960315.5680.5680                     True                            False
# 80105638.13140.13140                  False                            False
#
#                      meta.toxicity  \
# id
# 272953472.1207.1207              0
# 92960315.5680.5680               0
# 80105638.13140.13140     0.0386518
#
#                                                             meta.parsed  \
# id
# 272953472.1207.1207   [{'rt': 9, 'toks': [{'tok': '=', 'tag': 'NFP',...
# 92960315.5680.5680    [{'rt': 5, 'toks': [{'tok': '\n', 'tag': '', '...
# 80105638.13140.13140  [{'rt': 2, 'toks': [{'tok': ' ', 'tag': '', 'd...
#
#                                              meta.politeness_strategies  \
# id
# 272953472.1207.1207   {'feature_politeness_==Please==': 1, 'feature_...
# 92960315.5680.5680    {'feature_politeness_==Please==': 0, 'feature_...
# 80105638.13140.13140  {'feature_politeness_==Please==': 0, 'feature_...
#
#                                                 meta.politeness_markers  \
# id
# 272953472.1207.1207   {'politeness_markers_==Please==': [[('please',...
# 92960315.5680.5680    {'politeness_markers_==Please==': [], 'politen...
# 80105638.13140.13140  {'politeness_markers_==Please==': [], 'politen...
#
#                      meta.prediction meta.pred_score
# id
# 272953472.1207.1207                1        0.503996
# 92960315.5680.5680                 0         0.13428
# 80105638.13140.13140               0       0.0804226

# %%
test_utters_df.loc['473786014.2964.2956'].text
# Out:
# ' I dont want to seem rude or anything, but is there a reason external_link has gone unanswered and several have been resolved below? This editor and his suspected sockpuppets are continuing to commit rogue edits and action needs to be taken. Its getting frustrating to work on the page in question. Thanks,'

# %%
utt_with_attack = test_utters_df[test_utters_df['meta.comment_has_personal_attack']==True]
utt_attack_ids = utt_with_attack.index
print(len(utt_attack_ids))
# Out:
# 584

# %%
avg_polite_ness = 0
for u_id in utt_attack_ids:
    pred_score = test_utters_df.loc[u_id]['meta.pred_score']
    avg_polite_ness += pred_score

print(avg_polite_ness / len(utt_attack_ids))
# Out:
# 0.18280225979968698

# %%
utt_without_attack = test_utters_df[test_utters_df['meta.comment_has_personal_attack']==False]
utt_non_attack_ids = utt_without_attack.index
print(len(utt_non_attack_ids))
# Out:
# 5779

# %%
avg_polite_ness = 0
for u_id in utt_non_attack_ids:
    pred_score = test_utters_df.loc[u_id]['meta.pred_score']
    avg_polite_ness += pred_score

print(avg_polite_ness / len(utt_non_attack_ids))
# Out:
# 0.22239780898029585

# %%
pred_1 = pred_df[pred_df['prediction']==1]
utt_pos_ids = pred_1.index
print(len(utt_pos_ids))
# Out:
# 755

# %%
cnt = 0
for u_id in utt_pos_ids:
    if test_utters_df.loc[u_id]['meta.comment_has_personal_attack'] == True:
        cnt += 1
        print(test_utters_df.loc[u_id]['meta.pred_score'])
        print(test_utters_df.loc[u_id].text)
print("{} utterence has personal attack but was predicted to be polite.".format(cnt))

# %%
"""
utterance_ids = awry_corpus.get_utterance_ids()
rows = []

cnt = 0
for uid in utterance_ids:
    cnt += 1
    print(awry_corpus.get_utterance(uid).meta)
    if cnt > 2:
        break
    #rows.append(awry_corpus.get_utterance(uid).meta["Normalized Score"])
#politeness_strategies = pd.DataFrame(rows, index=utterance_ids)
"""

# %% [markdown]
# #### Sentiment

# %%
from pycorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP('http://localhost:9000')

# Function; Output = # sentence, # words, avg.sentimentValue, sentimentHist
def stanford_sentiment(text_str):
    res = nlp.annotate(text_str,
                   properties={
                       'annotators': 'sentiment',
                       'outputFormat': 'json',
                       'timeout': 40000,
                   })
    
    numSentence = len(res["sentences"])
    numWords = len(text_str.split())
    
    # data arrangement
    arraySentVal = np.zeros(numSentence)

    for i, s in enumerate(res["sentences"]):
        arraySentVal[i] = int(s["sentimentValue"])
        #print(int(s["sentimentValue"]), s["sentiment"])

    # sum of sentiment values 
    totSentiment = sum(arraySentVal)

    # avg. of sentiment values 
    avgSentiment = np.mean(arraySentVal)
    #print(avgSentiment)

    # frequency of sentimentValue
    bins = [0,1,2,3,4,5,6]
    freq = np.histogram(arraySentVal, bins)[0]    # getting freq. only w/o bins

    return(numSentence, numWords, totSentiment, avgSentiment, freq)

# %%
awry_ids = awry_corpus.get_utterance_ids()

# %%
col_names =  ['u_id', 'numSentence', 'numWords', 'totSentiment', 'avgSentiment']
df = pd.DataFrame(columns=col_names)

print("Total utterance: ", len(awry_ids))
cnt = 0
for uid in awry_ids:
    cnt += 1
    if cnt % 100 == 0:
        print(cnt)
    try:
        numSentence, numWords, totSentiment, avgSentiment, freq = stanford_sentiment(utterances.loc[uid].text)
        df.loc[len(df)] = [uid, numSentence, numWords, totSentiment, avgSentiment]
    except:
        print("error where uid =", uid)
    

outputFile = 'awry_sentiment.csv'
df.to_csv(outputFile, encoding='utf-8', index=False )
# Out:
# Total utterance:  6363
# error where uid = 146860774.13072.13072
# error where uid = 127772860.903.903
# 100
# 200
# error where uid = 370760170.48365.48343
# 300
# error where uid = 203503939.64709.64709
# error where uid = 203507415.65166.65166
# error where uid = 203516212.65308.65308
# error where uid = 316041793.7429.7429
# 400
# error where uid = 188454964.16448.16448
# 500
# 600
# 700
# 800
# error where uid = 128818551.16576.16567
# 900
# 1000
# 1100
# 1200
# error where uid = 448205040.3440.3432
# 1300
# 1400
# 1500
# 1600
# error where uid = 263284935.3024.3024
# error where uid = 320164597.6282.6282
# 1700
# error where uid = 240444038.11636.11624
# error where uid = 240849934.12703.12703
# error where uid = 276926669.1597.1597
# 1800
# 1900
# 2000
# error where uid = 38034311.3048.3048
# error where uid = 38043447.3278.3278
# error where uid = 38163583.3365.3365
# 2100
# 2200
# 2300
# 2400
# error where uid = 67570639.698.698
# 2500
# error where uid = 380375467.1864.1864
# error where uid = 380377424.2080.2080
# 2600
# 2700
# 2800
# 2900
# error where uid = 691647753.5281.5281
# 3000
# error where uid = 704215636.59.59
# 3100
# error where uid = 36500638.8566.8566
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# error where uid = 33441878.11535.11516
# 3800
# error where uid = 195674088.1944.1944
# 3900
# 4000
# 4100
# error where uid = 513895003.4458.4458
# 4200
# error where uid = 53014590.3765.3765
# error where uid = 44159321.5093.5093
# 4300
# error where uid = 111356721.3429.3182
# error where uid = 111357549.3546.3546
# 4400
# error where uid = 288656167.39129.39129
# error where uid = 288658031.40172.40172
# error where uid = 477000195.556.556
# 4500
# 4600
# error where uid = 131670830.3486.3476
# error where uid = 131673375.3846.3846
# 4700
# error where uid = 176927562.1164.1164
# 4800
# error where uid = 381938960.6141.6142
# 4900
# error where uid = 780668660.15480.15480
# error where uid = 151864178.879.879
# 5000
# error where uid = 256935248.721.721
# 5100
# error where uid = 176669824.14408.14408
# error where uid = 176746027.14535.14535
# error where uid = 176824876.14917.14917
# 5200
# 5300
# 5400
# 5500
# error where uid = 123267563.7207.7197
# error where uid = 123372019.7328.7328
# error where uid = 415934731.6483.6479
# 5600
# 5700
# 5800
# 5900
# error where uid = 120245026.7385.7385
# error where uid = 261581793.6368.6368
# error where uid = 194341434.43459.43459
# 6000
# error where uid = 234747790.16213.16184
# error where uid = 393326885.19760.19760
# 6100
# 6200
# error where uid = 73188468.24845.24834
# 6300
# error where uid = 32538509.8845.8847

# %%
stanford_sentiment(utterances.loc['34591966.61268.61268'].text)
# Out:
# 1 Negative
# 1 Negative
# 1 Negative
# 2 Neutral
# 2 Neutral
# 1 Negative
# 1 Negative
# 1 Negative
# 1.25
# (8, 141, 10.0, 1.25, array([0, 6, 2, 0, 0, 0], dtype=int64))

# %%
utterances.loc['34591966.61268.61268'].text
# Out:
# 'The parts I deleted were an unsubstantiated rant about ethnicity in Iran in the human rights section. It was little more than propaganda with no attempt to point to secondary material and anyway the English was appalling. I decided to make references to reports by HRW, Amnesty and UNCHR (I don\'t think these are pan-Arab or anti-Persian organisations), but also added a "criticism" section countering human rights allegations. I believe I summarised many of the points made before. But if you would like to expand on this and perhaps give reference to other secondary material substantiating the arguments, then go ahead. You, Zereshk, have made a point about the importance of secondary material to counter \'s analysis of Khuzestan\'s history. I believe I have met the standards of proof you are demanding. But this does not seem to be good enough. '

# %% [markdown]
# #### Read in sentiments for each utterance

# %%
sents = pd.read_csv('awry_sentiment.csv', index_col='u_id')
sents.head()
# Out:
#                        numSentence  numWords  totSentiment  avgSentiment
# u_id
# 146743638.12652.12652            1         4           2.0      2.000000
# 146743638.12667.12652            3        70           4.0      1.333333
# 146842219.12874.12874            4        86           8.0      2.000000
# 143890867.11926.11926            1         7           2.0      2.000000
# 143890867.11944.11926            4        19           6.0      1.500000
